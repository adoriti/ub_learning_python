# %%
import pandas as pd

# %%
    # Find out your current working directory
    import os
    print(os.getcwd())
    # Out: /Users/shane/Documents/blog
# Out:
# C:\Users\ASUS

# %%
os.chdir('C:\\Users\\ASUS\\Documents\\Ubiqum\\Python')

# %%
os.listdir(os.getcwd())
# Out:
# ['default of credit card clients.csv', 'example.csv']

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
# something like summary in R:
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
# are there missing values?
print(credit.isnull().values.any())
# Out:
# False

# %%
# make numericals into factors? here int into categorical
credit['SEX'].astype('category').cat.codes
credit['EDUCATION'].astype('category').cat.codes
credit['MARRIAGE'].astype('category').cat.codes
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
# 5        2
# 6        2
# 7        2
# 8        1
# 9        2
# 10       2
# 11       2
# 12       2
# 13       2
# 14       2
# 15       3
# 16       2
# 17       1
# 18       1
# 19       2
# 20       2
# 21       1
# 22       2
# 23       1
# 24       2
# 25       2
# 26       2
# 27       2
# 28       1
# 29       2
#         ..
# 29970    1
# 29971    1
# 29972    1
# 29973    1
# 29974    1
# 29975    1
# 29976    2
# 29977    2
# 29978    1
# 29979    1
# 29980    2
# 29981    1
# 29982    1
# 29983    1
# 29984    2
# 29985    2
# 29986    2
# 29987    2
# 29988    1
# 29989    2
# 29990    1
# 29991    1
# 29992    1
# 29993    2
# 29994    2
# 29995    1
# 29996    2
# 29997    2
# 29998    1
# 29999    1
# Length: 30000, dtype: int8

# %%
# try to see the categories
# sex_types = ['1', '2']
# credit.SEX.astype("category", sex_types).cat.codes
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
# 5        0
# 6        0
# 7        1
# 8        1
# 9        0
# 10       1
# 11       1
# 12       1
# 13       0
# 14       0
# 15       1
# 16       0
# 17       0
# 18       1
# 19       1
# 20       1
# 21       1
# 22       1
# 23       1
# 24       0
# 25       0
# 26       0
# 27       1
# 28       1
# 29       0
#         ..
# 29970    0
# 29971    0
# 29972    0
# 29973    0
# 29974    0
# 29975    0
# 29976    0
# 29977    0
# 29978    0
# 29979    0
# 29980    0
# 29981    0
# 29982    0
# 29983    0
# 29984    0
# 29985    0
# 29986    0
# 29987    0
# 29988    0
# 29989    0
# 29990    0
# 29991    0
# 29992    0
# 29993    0
# 29994    0
# 29995    0
# 29996    0
# 29997    0
# 29998    0
# 29999    0
# Length: 30000, dtype: int8

# %%
pd.get_dummies(credit, columns=['SEX'])
# Out:
#           ID  LIMIT_BAL  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          1      20000          2         1   24      2      2     -1     -1
# 1          2     120000          2         2   26     -1      2      0      0
# 2          3      90000          2         2   34      0      0      0      0
# 3          4      50000          2         1   37      0      0      0      0
# 4          5      50000          2         1   57     -1      0     -1      0
# 5          6      50000          1         2   37      0      0      0      0
# 6          7     500000          1         2   29      0      0      0      0
# 7          8     100000          2         2   23      0     -1     -1      0
# 8          9     140000          3         1   28      0      0      2      0
# 9         10      20000          3         2   35     -2     -2     -2     -2
# 10        11     200000          3         2   34      0      0      2      0
# ...

# %%
import matplotlib.pyplot as plt

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['EDUCATION'])
plt.show()

# %%
plt.hist(credit['AGE'])
plt.show()

# %%
plt.hist(credit['SEX'])
plt.show()

# %%
plt.hist(credit['MARRIAGE'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()
